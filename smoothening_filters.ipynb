# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("images/drmdm.jpg")
mean_blur=cv2.blur(img,(5,5))
median_blur=cv2.medianBlur(img,5)
gblur=cv2.GaussianBlur(img,(5,5),0)
plt.figure(figsize=(12,6))
plt.subplot(221)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title("Orignal image")
plt.subplot(222)
plt.imshow(cv2.cvtColor(mean_blur,cv2.COLOR_BGR2RGB))
plt.title("Mean blur of image")
plt.subplot(223)
plt.imshow(cv2.cvtColor(median_blur,cv2.COLOR_BGR2RGB))
plt.title("Median blur of image")
plt.subplot(224)
plt.imshow(cv2.cvtColor(gblur,cv2.COLOR_BGR2RGB))
plt.title("Gaussian b")
plt.tight_layout()
plt.show()
